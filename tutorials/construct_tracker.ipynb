# %% [markdown]
# [![Open in Google Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danielmlow/construct-tracker/blob/main/tutorials/construct_tracker.ipynb)
#
# # Tutorial to use construct-tracker to measure the constructs you choose in text:
#
# - Author: Daniel M. Low
# - License: Apache 2.0
# - Date: 29/07/2024
# - **If you use, please cite**: Low DM, Rankin O, Coppersmith DDL, Bentley KH, Nock MK, Ghosh SS (2024). Building lexicons with Generative AI result in lightweight and interpretable text models with high content validity. arXiv.

# %% [markdown]
# ### construct-tracker
# ##### - **lightweight**: no GPU needed (unlike LLMs)
# ##### - **private and free**: you can run on your local computer instead of submitting to a cloud API (OpenAI) which may not be secure
# ##### - **interpretable**: understand why the model outputs a given score, which can help avoid biases
# ##### - **high content validity**: measure what you actually want to measure (unlike existing lexicons or models that measure something only slightly related)
#
#
# <!-- There are three options:
# * **Lexicon**: Create a lexicon with Generative AI for the constructs you want to measure and obtain the counts of those constructs in text.
# * **Lexicon + construct-text similarity (CTS)**: find similar meaning phrases: Since counting exact matches will miss similar and relevant words, use CTS to include similar phrases. **recommended**
# * **Just construct-text similarity (CTS)**: skip creating a lexicon and just provide CTS with a few examples (might not work as well). No API key needed.  -->
#
#
# We provide A) "Quick start" section below followed by a B) "Use all special features" section

# %%
# Install construct-tracker 
# !pip install --upgrade construct-tracker
# Out:
# Requirement already satisfied: construct-tracker in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (1.0.12)
# Collecting construct-tracker
#   Downloading construct_tracker-1.0.13-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cython>=0.29.24 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (3.0.11)
# Requirement already satisfied: dill<0.4.0,>=0.3.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (0.3.9)
# Requirement already satisfied: litellm<2.0.0,>=1.35.28 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (1.59.0)
# Requirement already satisfied: nltk<4.0,>=3.8 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (3.9.1)
# Requirement already satisfied: numpy<1.26.5,>=1.19 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (1.26.4)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (0.12.2)
# Requirement already satisfied: sentence-transformers<3.0,>=2.7 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (2.7.0)
# Requirement already satisfied: spacy<3.8.0,>=3.7.3 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (3.7.5)
# Requirement already satisfied: statsmodels<0.15.0,>=0.14.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from construct-tracker) (0.14.4)
# Requirement already satisfied: aiohttp in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (3.11.11)
# Requirement already satisfied: click in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (8.1.8)
# Requirement already satisfied: httpx<0.28.0,>=0.23.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (0.27.2)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (8.6.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (3.1.5)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (4.23.0)
# Requirement already satisfied: openai>=1.55.3 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (1.59.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (2.10.5)
# Requirement already satisfied: python-dotenv>=0.2.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (1.0.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (0.8.0)
# Requirement already satisfied: tokenizers in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from litellm<2.0.0,>=1.35.28->construct-tracker) (0.21.0)
# Requirement already satisfied: joblib in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from nltk<4.0,>=3.8->construct-tracker) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from nltk<4.0,>=3.8->construct-tracker) (2024.11.6)
# Requirement already satisfied: tqdm in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from nltk<4.0,>=3.8->construct-tracker) (4.67.1)
# Requirement already satisfied: pandas>=0.25 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from seaborn<0.13.0,>=0.12.0->construct-tracker) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from seaborn<0.13.0,>=0.12.0->construct-tracker) (3.9.4)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from sentence-transformers<3.0,>=2.7->construct-tracker) (4.48.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from sentence-transformers<3.0,>=2.7->construct-tracker) (2.5.1)
# Requirement already satisfied: scikit-learn in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from sentence-transformers<3.0,>=2.7->construct-tracker) (1.6.1)
# Requirement already satisfied: scipy in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from sentence-transformers<3.0,>=2.7->construct-tracker) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from sentence-transformers<3.0,>=2.7->construct-tracker) (0.27.1)
# Requirement already satisfied: Pillow in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from sentence-transformers<3.0,>=2.7->construct-tracker) (11.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (0.15.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (2.32.3)
# Requirement already satisfied: setuptools in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.3->construct-tracker) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from statsmodels<0.15.0,>=0.14.2->construct-tracker) (1.0.1)
# Requirement already satisfied: anyio in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.35.28->construct-tracker) (4.8.0)
# Requirement already satisfied: certifi in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.35.28->construct-tracker) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.35.28->construct-tracker) (1.0.7)
# Requirement already satisfied: idna in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.35.28->construct-tracker) (3.10)
# Requirement already satisfied: sniffio in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.35.28->construct-tracker) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.35.28->construct-tracker) (0.14.0)
# Requirement already satisfied: filelock in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0,>=2.7->construct-tracker) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0,>=2.7->construct-tracker) (2024.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0,>=2.7->construct-tracker) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers<3.0,>=2.7->construct-tracker) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.35.28->construct-tracker) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.35.28->construct-tracker) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.35.28->construct-tracker) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.35.28->construct-tracker) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.35.28->construct-tracker) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm<2.0.0,>=1.35.28->construct-tracker) (0.22.3)
# Requirement already satisfied: language-data>=1.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.3->construct-tracker) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn<0.13.0,>=0.12.0->construct-tracker) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn<0.13.0,>=0.12.0->construct-tracker) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn<0.13.0,>=0.12.0->construct-tracker) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn<0.13.0,>=0.12.0->construct-tracker) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn<0.13.0,>=0.12.0->construct-tracker) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn<0.13.0,>=0.12.0->construct-tracker) (2.9.0.post0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from openai>=1.55.3->litellm<2.0.0,>=1.35.28->construct-tracker) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from openai>=1.55.3->litellm<2.0.0,>=1.35.28->construct-tracker) (0.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from pandas>=0.25->seaborn<0.13.0,>=0.12.0->construct-tracker) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from pandas>=0.25->seaborn<0.13.0,>=0.12.0->construct-tracker) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->litellm<2.0.0,>=1.35.28->construct-tracker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->litellm<2.0.0,>=1.35.28->construct-tracker) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.3->construct-tracker) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.3->construct-tracker) (2.3.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.3->construct-tracker) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.3->construct-tracker) (0.1.5)
# Requirement already satisfied: networkx in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0,>=2.7->construct-tracker) (3.2.1)
# Requirement already satisfied: sympy==1.13.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers<3.0,>=2.7->construct-tracker) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers<3.0,>=2.7->construct-tracker) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers<3.0,>=2.7->construct-tracker) (0.5.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.3->construct-tracker) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.3->construct-tracker) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.3->construct-tracker) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.3->construct-tracker) (7.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from aiohttp->litellm<2.0.0,>=1.35.28->construct-tracker) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from aiohttp->litellm<2.0.0,>=1.35.28->construct-tracker) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from aiohttp->litellm<2.0.0,>=1.35.28->construct-tracker) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from aiohttp->litellm<2.0.0,>=1.35.28->construct-tracker) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from aiohttp->litellm<2.0.0,>=1.35.28->construct-tracker) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from aiohttp->litellm<2.0.0,>=1.35.28->construct-tracker) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from aiohttp->litellm<2.0.0,>=1.35.28->construct-tracker) (1.18.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from scikit-learn->sentence-transformers<3.0,>=2.7->construct-tracker) (3.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from anyio->httpx<0.28.0,>=0.23.0->litellm<2.0.0,>=1.35.28->construct-tracker) (1.2.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.3->construct-tracker) (1.2.1)
# Requirement already satisfied: six>=1.5 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn<0.13.0,>=0.12.0->construct-tracker) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.3->construct-tracker) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.3->construct-tracker) (2.19.1)
# Requirement already satisfied: wrapt in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.3->construct-tracker) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/danielmlow/miniconda3/envs/ct/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.3->construct-tracker) (0.1.2)
# Downloading construct_tracker-1.0.13-py3-none-any.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 38.7 MB/s eta 0:00:00 0:00:01
# Installing collected packages: construct-tracker
#   Attempting uninstall: construct-tracker
#     Found existing installation: construct-tracker 1.0.12
#     Uninstalling construct-tracker-1.0.12:
#       Successfully uninstalled construct-tracker-1.0.12
# Successfully installed construct-tracker-1.0.13

# %%
# Import packages
import pandas as pd
import sys
import os
import shutil 
import datetime
import copy
from construct_tracker import lexicon

# %% [markdown]
# Let's create a lexicon to measure constructs related to insight and mindfulness. Here are some examples from a target dataset of documents (e.g., survey responses, social media posts).

# %%
documents = [
 'Every time I speak with my cousin Bob, I have great moments of insight, clarity, and wisdom',
 "He meditates a lot, but he's not super smart",
 'He is too competitive']

# %%
# Or load from Google Drive 
google_drive = False # Load files from Google Drive

if google_drive:
	current_path = '/content/drive/My Drive/Colab Notebooks'
	# Sign into drive to gain access to your documents in a dataframe and/or api_keys.py
	from google.colab import drive
	drive.mount('/content/drive')
	sys.path.append(current_path)
	# Change path and column name accordingly.
	documents = pd.read_csv('/content/drive/My Drive/insight_project/my_documents.csv')['documents_column'].tolist()

# %%
# load reddit posts and count 
# Info: https://zenodo.org/records/3941387
# Citation: Low, D. M., Rumker, L., Torous, J., Cecchi, G., Ghosh, S. S., & Talkar, T. (2020). Natural Language Processing Reveals Vulnerable Mental Health Support Groups and Heightened Health Anxiety on Reddit During COVID-19: Observational Study. Journal of medical Internet research, 22(10), e22635.

reddit_df = reddit_df = pd.read_csv('https://mair.sites.fas.harvard.edu/datasets/rmhd_27subreddits_1300posts_train.csv', index_col = 0)
reddit_df
# Out:
#            subreddit                author        date  \
# 0        EDAnonymous          lillylourose  2018/11/28
# 1        EDAnonymous          tinyTRONgirl  2019/10/15
# 2        EDAnonymous              Vetmyana  2019/07/02
# 3        EDAnonymous       Fastingcametome  2019/07/25
# 4        EDAnonymous             bananamo7  2019/04/19
# ...              ...                   ...         ...
# 28075  unitedkingdom      Anomalous-Entity  2019/05/07
# 28076  unitedkingdom            Squigglish  2019/03/28
# 28077  unitedkingdom             javaxcore  2019/09/02
# 28078  unitedkingdom  AlwaysGoForAusInRisk  2019/05/13
# 28079  unitedkingdom               Tyros43  2018/12/13
#
#                                                     post  \
# 0      The reason why I stoped with eating? Well, for...
# 1      I’m freaking out WHY can’t my body just digest...
# 2      Tw weight loss achievement Just lost 8lbs (wei...
# 3      When not eating is your solution to everything...
# 4      How to dedicate a long weekend to beginning re...
# ...                                                  ...
# 28075  When someone is having a go at the U.S. and ma...
# 28076  My MP voted against every single Indicative Mo...
# 28077  What is Order 66? I have heard much talk of th...
# 28078  Seeing the GB Ambassador for Denmark today at ...
# 28079  As an outsider looking in... As an outsider lo...
#
#        automated_readability_index  coleman_liau_index  \
# 0                         0.478964            2.747789
# 1                         5.559945            5.475852
# 2                         2.546452            4.004821
# 3                         0.836122            2.859536
# 4                         5.119444            6.724697
# ...                            ...                 ...
# 28075                     1.758324            4.527215
# 28076                     6.098205            9.032098
# 28077                     0.761500            2.701924
# 28078                     8.632452            8.773091
# 28079                     8.596646            7.857937
#
#        flesch_kincaid_grade_level  flesch_reading_ease  gulpease_index  \
# 0                        2.109524            95.205000       86.583333
# 1                        6.247874            80.769913       67.394161
# 2                        3.520194            91.910290       75.451613
# 3                        2.359891            95.598204       82.741497
# 4                        6.719444            70.932500       69.185185
# ...                           ...                  ...             ...
# 28075                    4.326374            77.275769       88.038462
# 28076                    6.976923            52.759744      104.384615
# 28077                    1.290000           103.625000       82.500000
# 28078                    9.139258            61.853071       60.968504
# 28079                    8.542880            68.991282       61.405063
#
#        gunning_fog_index  ...  tfidf_wish  tfidf_without  tfidf_wonder  \
# 0               4.761905  ...         0.0       0.000000           0.0
# 1               8.309854  ...         0.0       0.000000           0.0
# 2               4.960000  ...         0.0       0.254812           0.0
# 3               5.824762  ...         0.0       0.000000           0.0
# 4              10.585185  ...         0.0       0.000000           0.0
# ...                  ...  ...         ...            ...           ...
# 28075           6.048352  ...         0.0       0.000000           0.0
# 28076           7.887179  ...         0.0       0.000000           0.0
# 28077           4.000000  ...         0.0       0.000000           0.0
# 28078          12.296513  ...         0.0       0.000000           0.0
# 28079          11.444304  ...         0.0       0.000000           0.0
#
#        tfidf_work  tfidf_worri  tfidf_wors  tfidf_would  tfidf_wrong  \
# 0             0.0          0.0         0.0     0.000000     0.000000
# 1             0.0          0.0         0.0     0.131764     0.000000
# 2             0.0          0.0         0.0     0.000000     0.000000
# 3             0.0          0.0         0.0     0.000000     0.145753
# 4             0.0          0.0         0.0     0.000000     0.000000
# ...           ...          ...         ...          ...          ...
# 28075         0.0          0.0         0.0     0.258879     0.000000
# 28076         0.0          0.0         0.0     0.000000     0.000000
# 28077         0.0          0.0         0.0     0.000000     0.000000
# 28078         0.0          0.0         0.0     0.000000     0.000000
# 28079         0.0          0.0         0.0     0.000000     0.341362
#
#        tfidf_x200b  tfidf_year
# 0          0.00000         0.0
# 1          0.00000         0.0
# 2          0.00000         0.0
# 3          0.00000         0.0
# 4          0.00000         0.0
# ...            ...         ...
# 28075      0.00000         0.0
# 28076      0.00000         0.0
# 28077      0.00000         0.0
# 28078      0.00000         0.0
# 28079      0.37938         0.0
#
# [28080 rows x 350 columns]

# %%
if google_drive:
	# Sign into drive to gain access to your documents in a dataframe and/or api_keys.py
	
	
	lexicon_dir = current_path+'/ct_lexicons/' #to save from the lexicon
	output_dir = current_path+'/ct_datasets/' # to save final datasets
	# CHANGE PATH
	documents = pd.read_csv('/content/drive/My Drive/your_project_name/your_csv_file.csv')['documents_column_name'].tolist()
else:

	lexicon_dir = './ct_lexicons/' #to save from the lexicon
	output_dir = './ct_datasets/' # to save final datasets

os.makedirs(lexicon_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# # Create lexicon with generative AI
#
# If you want to use generative AI models from python, you need to provide a key from a given provider (e.g., OpenAI, Google, etc.). Alternatively, you can use chatgpt, bing or other browsers, to obtain a list and then copy and paste when indicated below.

# %% [markdown]
# # Set OpenRouterAI API key and choose model
# - API key is associated to your account. Create an account by signing in here, adding credits and creating an API key here: https://openrouter.ai/
#
# - All models: https://openrouter.ai/models
#     - Paid models:
#         - 'gpt-4o' (recommended)
#         - 'gpt-4o-mini' (cheaper)
#         - 'anthropic/claude-3.5-sonnet' (recommended)
#     - Free models: https://openrouter.ai/models?max_price=0
#         - free models: certain requests per minute (e.g., 2) and certain requests per day (depends on model). See https://openrouter.ai/docs/limits
#         - "google/gemini-2.0-flash-exp:free"
#         - "meta-llama/llama-3.1-70b-instruct:free"
#         - "meta-llama/llama-3.1-8b-instruct:free"

# %% [markdown]
# Add your private API key. get it from OpenRouter AI: https://openrouter.ai/settings/keys
#
# - (a) 'input_box': past key into the input box that will appear below the cell or at the top of the screen. This keeps it hidden in case you share this notebook with someone.
# - (b) 'add_manually': assign it to the variable. But then do not share this notebook publically or others can use your key.
# - (c) 'google_drive': add a file on google drive called api_keys.py with a variable called openrouter_key = 'YOUR_KEY'
# - (d) 'local': add a file on your local computer called api_keys.py with a variable called openrouter_key = 'YOUR_KEY'. Careful with sharing that file. Add it to your .gitignore if you're using github.

# %%
add_api_key = 'local' 

if add_api_key == 'input_box':
	# This key will only work for free models. get your own and add some dollars from OpenRouter AI: https://openrouter.ai/settings/keys
	# Here is one of mine with $0 "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" that might work
	OPENROUTER_API_KEY = input('Add key (input box may appear at the top of the notebook or below):') 
	
elif add_api_key == 'add_manually':
	OPENROUTER_API_KEY = 'YOUR-API-KEY'

elif add_api_key == 'google_drive':
# Sign into drive to gain access to your documents in a dataframe and/or api_keys.py
	from google.colab import drive
	drive.mount('/content/drive')
	sys.path.append('/content/drive/My Drive/Colab Notebooks')
	import api_keys
	OPENROUTER_API_KEY = api_keys.openrouter_key 
elif add_api_key == 'local':
	try:
		import api_keys
		OPENROUTER_API_KEY = api_keys.openrouter_key 
	except:
		print("Module 'api_key' not found. Add your key here. ") 
os.environ["api_key"]  = OPENROUTER_API_KEY

# %% [markdown]
# Now specify which model to use

# %%
model = 'gpt-4o-mini' # Many options including: "gpt-4o", "gpt-4o-mini" (cheaper), 'meta-llama/llama-3.1-70b-instruct:free' (free for like a few a minute, won't work for the whole tutorial)  others: https://openrouter.ai/models

# %% [markdown]
# # A. Quick start

# %% [markdown]
# ### 1. Build lexicon with Generative AI and then count in documents

# %%
my_lexicon = lexicon.Lexicon()         # Initialize lexicon

my_lexicon.add('Insight', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	  examples = ['insight', 'realized'])

my_lexicon.add('Mindfulness', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	examples = ['mindfulness', 'meditate'])

my_lexicon.add('Compassion', section = 'tokens', value = 'create', source = model, max_tokens = 150,
	examples = ['compassion', 'love', 'kind', 'help others'])

# max_tokens=150 because creating larger lexicons will be harder to validate and will take longer to generate, but you can experiment.
# Out:
# INFO: Adding 'Insight' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Insight']
# INFO: Adding 'Mindfulness' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Mindfulness']
# INFO: Adding 'Compassion' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Compassion']

# %% [markdown]
# 1.1. View lexicons

# %%
print(my_lexicon.constructs['Insight']['tokens'])

print(my_lexicon.constructs['Mindfulness']['tokens'])

print(my_lexicon.constructs['Compassion']['tokens'])
# Out:
# ['acumen', 'analysis', 'analytical thinking', 'astuteness', 'awareness', 'breakthrough', 'clarity', 'clarity of thought', 'clarity of vision', 'cognitive awareness', 'comprehension', 'critical thinking', 'deep dive', 'deep understanding', 'discern', 'discernment', 'discovery', 'enlightenment', 'epiphany', 'foresight', 'grasp', 'insight', 'insight-driven', 'insightfully', 'insightfulness', 'interpretation', 'intuition', 'intuition-based', 'keen observation', 'knowledge', 'lucidity', 'mental clarity', 'observation', 'perception', 'perceptive', 'perceptiveness', 'perspective', 'profound', 'realization', 'realized', 'recognition', 'reflection', 'revelation', 'sagacity', 'self-awareness', 'shrewdness', 'thoughtful', 'thoughtful analysis', 'uncover', 'understanding', 'unveil', 'unveil insights', 'unveilment', 'wisdom']
# ['acceptance', 'attention', 'authenticity', 'awareness', 'awareness of breath', 'balance', 'body scan', 'breathing', 'breathwork', 'calm', 'centering', 'clarity', 'compassion', 'connection', 'detachment', 'emotions', 'equanimity', 'flow', 'focus', 'gratitude', 'grounding', 'grounding techniques', 'harmony', 'here', 'insight', 'intention', 'journey', 'joy', 'listening', 'loving-kindness', 'meditate', 'mindful eating', 'mindful movement', 'mindful walking', 'mindfulness', 'moment', 'nature', 'non-judgment', 'now', 'nurturing', 'observation', 'openness', 'patience', 'peace', 'practice', 'presence', 'present moment', 'reflection', 'release', 'resilience', 'self-awareness', 'self-care', 'self-reflection', 'sensations', 'silence', 'simplicity', 'stillness', 'surrender', 'thoughts', 'tranquility', 'visualization']
# ['altruism', 'benevolence', 'caring', 'charity', 'comfort', 'community', 'compassion', 'compassion and kindness', 'compassion fatigue', 'compassion for others', 'compassion for self', 'compassion for the planet', 'compassion in action', 'compassion in education', 'compassion in healthcare', 'compassion in leadership', 'compassion in relationships', 'compassion in the', 'compassion journey', 'compassion meditation', 'compassion practice', 'compassion towards animals', 'compassion training', 'compassionately', 'connection', 'emotional support', 'empathy', 'encouragement', 'forgiveness', 'generosity', 'goodwill', 'healing', 'heart', 'help others', 'humanity', 'kind', 'kindness', 'listening', 'love', 'mercy', 'mindfulness', 'nurturing', 'outreach', 'patience', 'presence', 'respect', 'selflessness', 'service', 'share', 'solace', 'support', 'sympathy', 'tenderness', 'togetherness', 'understanding', 'uplift', 'warmth']

# %% [markdown]
# 1.2. Now count whether tokens appear in document:

# %%
counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,
                                                                                      normalize = False,
                                                                                      )

display(counts)
# Out:
# extracting...
#   0%|          | 0/3 [00:00<?, ?it/s]WARNING: Lemmatizing the lexicon tokens. We recommend you lemmatize before extracting (my_lexicon = lemmatize_tokens(my_lexicon)) so you can save time if you want to repeat extraction on different documents.
#  33%|███▎      | 1/3 [00:00<00:00,  3.39it/s]WARNING: Lemmatizing the lexicon tokens. We recommend you lemmatize before extracting (my_lexicon = lemmatize_tokens(my_lexicon)) so you can save time if you want to repeat extraction on different documents.
#  67%|██████▋   | 2/3 [00:00<00:00,  3.43it/s]WARNING: Lemmatizing the lexicon tokens. We recommend you lemmatize before extracting (my_lexicon = lemmatize_tokens(my_lexicon)) so you can save time if you want to repeat extraction on different documents.
# 100%|██████████| 3/3 [00:00<00:00,  3.67it/s]
#    document_id                                           document  Insight  \
# 0            0  Every time I speak with my cousin Bob, I have ...        3
# 1            1       He meditates a lot, but he's not super smart        0
# 2            2                              He is too competitive        0
#
#    Mindfulness  Compassion  word_count
# 0            3           0          17
# 1            1           0           8
# 2            0           0           4

# %% [markdown]
# You can save files. If you're on google colab you need to mount google Drive (see code above):
#
# ```python
# counts.to_csv(f'{output_dir}insight_lexicon_counts.csv', index = False)
# ```

# %% [markdown]
# 1.3. Interpret counts: visualize matches in context

# %%
construct = 'Mindfulness'
print(f'Matches for {construct}:')
lexicon.highlight_matches(documents, construct, matches_construct2doc, max_matches = 2)
print()


construct = 'Insight'
print(f'Matches for {construct}:')
lexicon.highlight_matches(documents, construct,matches_construct2doc, max_matches = 2)
print()
# Out:
# Matches for Mindfulness:
# He <mark>meditate</mark>s a lot, but he's not super smart
# Every time I speak with my cousin Bob, I have great <mark>moment</mark>s of <mark>insight</mark>, <mark>clarity</mark>, and wisdom
# Matches for Insight:

# %% [markdown]
# # B. Use all special features
#
# Recommended: download and run this on your local computer using jupyter lab, vscode, or your favorite development environment. Saving to and from files is quicker if run locally on your computer than on Google Drive.

# %% [markdown]
# ### 1. Build lexicon with Generative AI
#
#
# #### Lexicon step 1.1: First provide api keys and general info on the lexicon

# %%
my_lexicon = lexicon.Lexicon()			# Initialize lexicon
my_lexicon.name = 'Insight'		# Set lexicon name
my_lexicon.description = 'Insight lexicon with constructs inspired by items of the Emotional Insight Scale'
my_lexicon.creator = 'DML' 				# your name or initials for transparency in logging who made changes
my_lexicon.version = '1.0'				# Set version. Over time, others may modify your lexicon, so good to keep track. MAJOR.MINOR. (e.g., MAJOR: new constructs or big changes to a construct, Minor: small changes to a construct)

# %%
# Fill out this information
domain = 'psychology' # Optional: bias definitions to a certain domain. this can be "mental health", "economics" or set to None (no quotation marks)
models_for_lexicon = [model] # Here you could add more: [model,command_nightly]
model_for_definition = model # You can ask model to create definition for each construct in the lexicon. Or set to None (no quotation marks)
temperatures = [0,0.5,1] # Temperature is another important parameter that defines how creative a model should be (0: a model outputs the most probable tokens given the prompt and training data; 1=more creative and less predictable responses, with a maximum of 2, which is not often used).

# %% [markdown]
# #### Lexicon step 1.2: Add examples and definitions manually or using a model
#
# **Examples**
#
# Add a few prototypical tokens you don't want to miss. With these examples, help guide the model as to whether you want adjectives, nouns, phrases or all of the above.
#
#
# **Definitions**
#
# We recommend this for expert validation (step after creating the lexicon, so raters can decide whether to include a token as a function of a specific definition). However, you can decide whether the Generative AI model sees the definition or not so as to guide or not guide the lexicon creation.
#
# We'll show an example where we manually provided a definition (insight), where we'll have our model provide it, and where we will not include it.

# %%
# Fill in

construct_information = {
	'Insight': {
		'examples': ['clarity', 'enlightenment', 'wise'],
		'definition': "the clarity of understanding of one's thoughts, feelings and behavior",
		'reference': "Grant, A. M., Franklin, J., & Langford, P. (2002). The self-reflection and insight scale: A new measure of private self-consciousness. Social Behavior and Personality: an international journal, 30(8), 821-835."
			 },
	'Mindfulness': {
		'examples': ['mindful','meditation', 'awareness', 'nonjudgemental', 'present-focused'],
		'definition': model_for_definition, # it will later check if definition == model_for_definition, if it does, it will generate using that model
		'reference':model_for_definition
			 },	
	'Compassion': {
		'examples':['compassion', 'love', 'kind', 'help others'],
		'definition': None,
		'reference':None
			 },
}

## Definition will be added if model_for_definition is not None using our own prompt. Or you can can directly prompt APIs here with your own prompt. This is our default one:
# prompt = f"Provide a brief definition of {construct} (in the {domain} domain). Provide reference in APA format where you got it from. Return result in the following format: {'{construct}': 'the_definition', 'reference':'the_reference'}"
# definition = api_request(prompt, model = model)

# %%
# Loop through constructs and generate lexicon and definition as instructed above in construct_information

for construct, information in construct_information.items():
	print('\n',construct, ' ------------------------')
	examples, definition, reference = information['examples'], information['definition'], information['reference']
	
	# DEFINITION: add definition or use model to get one
	# ===================================================
	construct_dict = construct_information.get(construct)
	# if definition exists (is str), use it.
	if construct_dict['definition'] == model_for_definition:
		# Use model to create a definition
		definition, reference = my_lexicon.generate_definition(construct, model = model_for_definition, domain=domain)
		print(f'Generated definition: {definition}\n')
		print(f'Reference: {reference}\n')
		# Update with definition
		construct_information[construct] = {'definition': definition, 'reference': reference}
	elif isinstance(construct_dict['definition'], str):
		definition = construct_dict['definition']
		reference = construct_dict['reference']
	elif construct_dict['definition'] == None:
		definition = None
		reference = None

	# PROMPT: add definition and examples to prompt
	# ===================================================
	prompt = lexicon.generate_prompt(construct,
                         prompt_name=construct,
                         domain = domain,
						 definition = definition,
						 examples = examples)
	
	print('Prompt used:')
	print(prompt)
	print()

	'''
	## Or create your own prompt here:
	prompt = """
	 Create a list of words and phrases related to {construct} in the {domain} domain. Here are some examples: {examples}
	 """
	prompt.format(construct = construct, domain = domain, example = examples)
	print(prompt)
	'''

	# Generate lexicon
	# ===================================================
	# Each model and temperature will create redudant and new tokens. They will merge with other tokens already generated. 
	for model in models_for_lexicon:
		for temperature in temperatures:
			my_lexicon.add(construct, section = 'tokens', value = 'create', prompt = prompt, source = model, temperature = temperature, max_tokens = 150,
				# so these are saved to metadata
				domain = domain, examples = examples, definition = definition,definition_references = reference)
	print('Models used to generate tokens:')
	[print(n) for n in list(my_lexicon.constructs[construct]['tokens_metadata'].keys())]
	print()
	print('Generated lexicon:', my_lexicon.constructs[construct]['tokens']) 
	print()
# Out:
# INFO: Adding 'Insight' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Insight']
#  Insight  ------------------------
# Prompt used:
# Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.
# Here is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior
# Here are some examples (include these in the list): clarity; enlightenment; wise
#
# Models used to generate tokens:
# gpt-4o-mini, temperature-0, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-04.346697
# gpt-4o-mini, temperature-0.5, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-08.028427
# gpt-4o-mini, temperature-1, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-11.554414
#
# Generated lexicon: ['acceptance', 'acknowledgment', 'analysis', 'awaken', 'awareness', 'awareness of self', 'behavioral insight', 'breakthrough', 'clarity', 'clarity of feeling', 'clarity of mind', 'clarity of perception', 'clarity of thought', 'cognition', 'cognitive', 'cognitive clarity', 'cognitive insight', 'coherence', 'comprehension', 'conscious thought', 'contemplation', 'critical thinking', 'deep understanding', 'delve', 'depth', 'depth of understanding', 'discernment', 'emotional awareness', 'emotional clarity', 'emotional intelligence', 'enlightenment', 'epiphany', 'focus', 'grasp', 'growth', 'holistic', 'inner vision', 'inner voice', 'inner wisdom', 'insightfulness', 'interpret', 'introspection', 'introspective journey', 'intuition', 'knowledge', 'learning', 'life lessons', 'lucidity', 'mental clarity', 'mental insight', 'mindfulness', 'observation', 'perception', 'perceptual insight', 'personal growth', 'personal insight', 'perspective', 'profound realization', 'profound understanding', 'psychological insight', 'realization', 'recognition', 'reflection', 'revelation', 'self-awareness', 'self-discovery', 'self-examination', 'self-illumination', 'self-knowledge', 'self-realization', 'self-reflection', 'situational awareness', 'synthesis', 'transformative insight', 'transparency', 'true self', 'truth', 'understanding', 'understanding oneself', 'understanding self', 'unveil', 'unveil emotions', 'wisdom', 'wise']
#
#
#  Mindfulness  ------------------------
# INFO: Adding 'Mindfulness' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Mindfulness']
# invalid syntax (<string>, line 1)
# Error parsing string in content: {'id': 'gen-1737496274-zCocHH6WayoUJXm5LihH', 'provider': 'OpenAI', 'model': 'openai/gpt-4o-mini', 'object': 'chat.completion', 'created': 1737496274, 'choices': [{'logprobs': None, 'finish_reason': 'stop', 'native_finish_reason': 'stop', 'index': 0, 'message': {'role': 'assistant', 'content': '```json\n{"Mindfulness": "Mindfulness is the psychological process of bringing one\'s attention to the present moment, which can be cultivated through meditation and other practices, and is often associated with increased awareness and acceptance of one\'s thoughts, feelings, and bodily sensations.", "reference":"Kabat-Zinn, J. (1990). Full Catastrophe Living: Using the Wisdom of Your Body and Mind to Face Stress, Pain, and Illness. Delacorte."}\n```', 'refusal': ''}}], 'system_fingerprint': 'fp_72ed7ab54c', 'usage': {'prompt_tokens': 56, 'completion_tokens': 96, 'total_tokens': 152}}. Will try by splitting
# New definition:
# "Mindfulness": "Mindfulness is the psychological process of bringing one's attention to the present moment, which can be cultivated through meditation and other practices, and is often associated with increased awareness and acceptance of one's thoughts, feelings, and bodily sensations.",
# Reference: gpt-4o-mini which references: ":"Kabat-Zinn, J. (1990). Full Catastrophe Living: Using the Wisdom of Your Body and Mind to Face Stress, Pain, and Illness. Delacorte."
#
# Generated definition:
# "Mindfulness": "Mindfulness is the psychological process of bringing one's attention to the present moment, which can be cultivated through meditation and other practices, and is often associated with increased awareness and acceptance of one's thoughts, feelings, and bodily sensations.",
#
# Reference: gpt-4o-mini which references: ":"Kabat-Zinn, J. (1990). Full Catastrophe Living: Using the Wisdom of Your Body and Mind to Face Stress, Pain, and Illness. Delacorte."
#
#
# Prompt used:
# Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.
# Here is a definition of Mindfulness: "mindfulness": "mindfulness is the psychological process of bringing one's attention to the present moment, which can be cultivated through meditation and other practices, and is often associated with increased awareness and acceptance of one's thoughts, feelings, and bodily sensations.",
# Here are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused
# INFO: Adding 'Compassion' to the lexicon (it was not previously there). If you meant to add to an existing construct (and have a typo in the construct name, which is case sensitive), run: del your_lexicon_name.constructs['Compassion']
# Models used to generate tokens:
# gpt-4o-mini, temperature-0, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-16.047825
# gpt-4o-mini, temperature-0.5, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-18.718109
# gpt-4o-mini, temperature-1, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-21.401681
#
# Generated lexicon: ['acceptance', 'acceptance and commitment', 'acceptance and commitment therapy', 'acceptance of feelings', 'acceptance of self', 'acceptance practice', 'alertness', 'attention', 'awareness', 'awareness of body', 'awareness of breath', 'awareness of feelings', 'awareness of sensations', 'awareness of thoughts', 'awareness training', 'body scan', 'breath', 'breathing', 'clarity', 'cognitive flexibility', 'compassion', 'conscious awareness', 'cultivating presence', 'deep listening', 'detachment', 'disengagement', 'emotional regulation', 'emotions', 'equanimity', 'feelings', 'flow state', 'flowing', 'focus', 'gratitude', 'grounding', 'harmony', 'inner peace', 'intention', 'intention setting', 'introspection', 'kindness', 'letting go', 'listening', 'loving-kindness', 'meditation', 'mental clarity', 'mindful', 'mindful awareness', 'mindful breathing', 'mindful communication', 'mindful eating', 'mindful journaling', 'mindful listening', 'mindful movement', 'mindful walking', 'mindfulness practice', 'mindfulness practices', 'mindfulness-based stress reduction', 'moment to moment', 'non-jud', 'non-reactivity', 'nonjudgemental', 'observation', 'open awareness', 'openness', 'patience', 'presence', 'present moment', 'present-focused', 'reflection', 'relaxation', 'resilience', 'self-acceptance', 'self-awareness', 'self-compassion', 'self-reflection', 'self-regulation', 'sensations', 'sensory awareness', 'sensory experience', 'stillness', 'stress reduction', 'thoughts', 'visualization', 'waking up', 'wellbeing']
#
#
#  Compassion  ------------------------
# Prompt used:
# Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.
# Here are some examples (include these in the list): compassion; love; kind; help others
#
# Models used to generate tokens:
# gpt-4o-mini, temperature-0, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-24.307125
# gpt-4o-mini, temperature-0.5, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-27.604252
# gpt-4o-mini, temperature-1, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-30.595736
#
# Generated lexicon: ['acceptance', 'active listening', 'advocacy', 'altruism', 'assist', 'attachment', 'awareness', 'benevolence', 'bonding', 'care', 'caring', 'charity', 'closeness', 'communal care', 'community', 'companionship', 'compassion', 'compassion awareness', 'compassion cultivation', 'compassion development', 'compassion fatigue', 'compassion for others', 'compassion for self', 'compassion in action', 'compassion interventions', 'compassion meditation', 'compassion mindset', 'compassion practice', 'compassion research', 'compassion skills', 'compassion training', 'compassion-focused therapy', 'compassionate communication', 'compassionate leadership', 'compassionate response', 'concern', 'connection', 'consideration', 'embrace', 'emotional attunement', 'emotional intelligence', 'emotional support', 'empathy', 'encouragement', 'engagement', 'forgiveness', 'generosity', 'gentleness', 'grace', 'healing', 'help others', 'human connection', 'humanity', 'inclusion', 'kind', 'kindness', 'listening', 'love', 'love in action', 'mercy', 'mindfulness', 'non-judgment', 'nonjudgmental', 'nurturing', 'openness', 'outreach', 'patience', 'positive regard', 'presence', 'psychological safety', 'reassurance', 'relational', 'relational care', 'relational empathy', 'resilience', 'respect', 'responsiveness', 'self-comp', 'self-compassion', 'selflessness', 'service', 'shared humanity', 'social support', 'solace', 'solidarity', 'support', 'sympathy', 'tenderness', 'trust', 'understanding', 'uplift', 'uplifting', 'upliftment', 'validation', 'vulnerability', 'warmth']

# %% [markdown]
# #### Lexicon step 1.3: Important: review resulting lexicon. Add or remove tokens manually.

# %%
for construct in construct_information.keys():
	print(f"{construct}:", my_lexicon.constructs[construct]['tokens'])
# Out:
# Insight: ['acceptance', 'acknowledgment', 'analysis', 'awaken', 'awareness', 'awareness of self', 'behavioral insight', 'breakthrough', 'clarity', 'clarity of feeling', 'clarity of mind', 'clarity of perception', 'clarity of thought', 'cognition', 'cognitive', 'cognitive clarity', 'cognitive insight', 'coherence', 'comprehension', 'conscious thought', 'contemplation', 'critical thinking', 'deep understanding', 'delve', 'depth', 'depth of understanding', 'discernment', 'emotional awareness', 'emotional clarity', 'emotional intelligence', 'enlightenment', 'epiphany', 'focus', 'grasp', 'growth', 'holistic', 'inner vision', 'inner voice', 'inner wisdom', 'insightfulness', 'interpret', 'introspection', 'introspective journey', 'intuition', 'knowledge', 'learning', 'life lessons', 'lucidity', 'mental clarity', 'mental insight', 'mindfulness', 'observation', 'perception', 'perceptual insight', 'personal growth', 'personal insight', 'perspective', 'profound realization', 'profound understanding', 'psychological insight', 'realization', 'recognition', 'reflection', 'revelation', 'self-awareness', 'self-discovery', 'self-examination', 'self-illumination', 'self-knowledge', 'self-realization', 'self-reflection', 'situational awareness', 'synthesis', 'transformative insight', 'transparency', 'true self', 'truth', 'understanding', 'understanding oneself', 'understanding self', 'unveil', 'unveil emotions', 'wisdom', 'wise']
# Mindfulness: ['acceptance', 'acceptance and commitment', 'acceptance and commitment therapy', 'acceptance of feelings', 'acceptance of self', 'acceptance practice', 'alertness', 'attention', 'awareness', 'awareness of body', 'awareness of breath', 'awareness of feelings', 'awareness of sensations', 'awareness of thoughts', 'awareness training', 'body scan', 'breath', 'breathing', 'clarity', 'cognitive flexibility', 'compassion', 'conscious awareness', 'cultivating presence', 'deep listening', 'detachment', 'disengagement', 'emotional regulation', 'emotions', 'equanimity', 'feelings', 'flow state', 'flowing', 'focus', 'gratitude', 'grounding', 'harmony', 'inner peace', 'intention', 'intention setting', 'introspection', 'kindness', 'letting go', 'listening', 'loving-kindness', 'meditation', 'mental clarity', 'mindful', 'mindful awareness', 'mindful breathing', 'mindful communication', 'mindful eating', 'mindful journaling', 'mindful listening', 'mindful movement', 'mindful walking', 'mindfulness practice', 'mindfulness practices', 'mindfulness-based stress reduction', 'moment to moment', 'non-jud', 'non-reactivity', 'nonjudgemental', 'observation', 'open awareness', 'openness', 'patience', 'presence', 'present moment', 'present-focused', 'reflection', 'relaxation', 'resilience', 'self-acceptance', 'self-awareness', 'self-compassion', 'self-reflection', 'self-regulation', 'sensations', 'sensory awareness', 'sensory experience', 'stillness', 'stress reduction', 'thoughts', 'visualization', 'waking up', 'wellbeing']
# Compassion: ['acceptance', 'active listening', 'advocacy', 'altruism', 'assist', 'attachment', 'awareness', 'benevolence', 'bonding', 'care', 'caring', 'charity', 'closeness', 'communal care', 'community', 'companionship', 'compassion', 'compassion awareness', 'compassion cultivation', 'compassion development', 'compassion fatigue', 'compassion for others', 'compassion for self', 'compassion in action', 'compassion interventions', 'compassion meditation', 'compassion mindset', 'compassion practice', 'compassion research', 'compassion skills', 'compassion training', 'compassion-focused therapy', 'compassionate communication', 'compassionate leadership', 'compassionate response', 'concern', 'connection', 'consideration', 'embrace', 'emotional attunement', 'emotional intelligence', 'emotional support', 'empathy', 'encouragement', 'engagement', 'forgiveness', 'generosity', 'gentleness', 'grace', 'healing', 'help others', 'human connection', 'humanity', 'inclusion', 'kind', 'kindness', 'listening', 'love', 'love in action', 'mercy', 'mindfulness', 'non-judgment', 'nonjudgmental', 'nurturing', 'openness', 'outreach', 'patience', 'positive regard', 'presence', 'psychological safety', 'reassurance', 'relational', 'relational care', 'relational empathy', 'resilience', 'respect', 'responsiveness', 'self-comp', 'self-compassion', 'selflessness', 'service', 'shared humanity', 'social support', 'solace', 'solidarity', 'support', 'sympathy', 'tenderness', 'trust', 'understanding', 'uplift', 'uplifting', 'upliftment', 'validation', 'vulnerability', 'warmth']

# %% [markdown]
# Add or remove tokens in a list that definitely should /shouldn't be there. BE CAREFUL WITH TYPOS OR MISPELLINGS.
#
# In source you can add any additional description. Recommend putting your initials as well available in `my_lexicon.creator`.

# %%
print(my_lexicon.creator)
my_lexicon.add('Mindfulness', section ='tokens',value = ['meditate', 'pay attention'], source=my_lexicon.creator + ": added a few verb forms") # Up to you as an expert
my_lexicon.remove('Mindfulness', remove_tokens = ['being', 'flow'], source =my_lexicon.creator + ": might capture non-compassion-related context too often") # Up to you as an expert
# Out:
# DML

# %% [markdown]
# Now those appear as entries in the metadata. All additions are merged and all removed are removed

# %%
for n in my_lexicon.constructs['Mindfulness']['tokens_metadata'].keys():
	print('action: ', 
	my_lexicon.constructs['Mindfulness']['tokens_metadata'][n]['action'],
	'; from source: ',
	n)
# Out:
# action:  create ; from source:  gpt-4o-mini, temperature-0, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-16.047825
# action:  create ; from source:  gpt-4o-mini, temperature-0.5, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-18.718109
# action:  create ; from source:  gpt-4o-mini, temperature-1, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-21.401681
# action:  manually added ; from source:  DML: added a few verb forms 25-01-21T21-51-37.825581
# action:  remove ; from source:  DML: might capture non-compassion-related context too often 25-01-21T21-51-37.826021

# %% [markdown]
# Or export to csv, rate spreadsheat and import back into python.
#
# See section "Validate with experts or just crowdsourcing" below on how to code and reload spreadsheet back into python

# %% [markdown]
# #### Lexicon step 1.4: Confirm additions and removals were successful.
#
# `['tokens']` contains the final tokens.

# %%
for construct in construct_information.keys():
	print(f"{construct}:",my_lexicon.constructs[construct]['tokens'])
# Out:
# Insight: ['acceptance', 'acknowledgment', 'analysis', 'awaken', 'awareness', 'awareness of self', 'behavioral insight', 'breakthrough', 'clarity', 'clarity of feeling', 'clarity of mind', 'clarity of perception', 'clarity of thought', 'cognition', 'cognitive', 'cognitive clarity', 'cognitive insight', 'coherence', 'comprehension', 'conscious thought', 'contemplation', 'critical thinking', 'deep understanding', 'delve', 'depth', 'depth of understanding', 'discernment', 'emotional awareness', 'emotional clarity', 'emotional intelligence', 'enlightenment', 'epiphany', 'focus', 'grasp', 'growth', 'holistic', 'inner vision', 'inner voice', 'inner wisdom', 'insightfulness', 'interpret', 'introspection', 'introspective journey', 'intuition', 'knowledge', 'learning', 'life lessons', 'lucidity', 'mental clarity', 'mental insight', 'mindfulness', 'observation', 'perception', 'perceptual insight', 'personal growth', 'personal insight', 'perspective', 'profound realization', 'profound understanding', 'psychological insight', 'realization', 'recognition', 'reflection', 'revelation', 'self-awareness', 'self-discovery', 'self-examination', 'self-illumination', 'self-knowledge', 'self-realization', 'self-reflection', 'situational awareness', 'synthesis', 'transformative insight', 'transparency', 'true self', 'truth', 'understanding', 'understanding oneself', 'understanding self', 'unveil', 'unveil emotions', 'wisdom', 'wise']
# Mindfulness: ['acceptance', 'acceptance and commitment', 'acceptance and commitment therapy', 'acceptance of feelings', 'acceptance of self', 'acceptance practice', 'alertness', 'attention', 'awareness', 'awareness of body', 'awareness of breath', 'awareness of feelings', 'awareness of sensations', 'awareness of thoughts', 'awareness training', 'body scan', 'breath', 'breathing', 'clarity', 'cognitive flexibility', 'compassion', 'conscious awareness', 'cultivating presence', 'deep listening', 'detachment', 'disengagement', 'emotional regulation', 'emotions', 'equanimity', 'feelings', 'flow state', 'flowing', 'focus', 'gratitude', 'grounding', 'harmony', 'inner peace', 'intention', 'intention setting', 'introspection', 'kindness', 'letting go', 'listening', 'loving-kindness', 'meditate', 'meditation', 'mental clarity', 'mindful', 'mindful awareness', 'mindful breathing', 'mindful communication', 'mindful eating', 'mindful journaling', 'mindful listening', 'mindful movement', 'mindful walking', 'mindfulness practice', 'mindfulness practices', 'mindfulness-based stress reduction', 'moment to moment', 'non-jud', 'non-reactivity', 'nonjudgemental', 'observation', 'open awareness', 'openness', 'patience', 'pay attention', 'presence', 'present moment', 'present-focused', 'reflection', 'relaxation', 'resilience', 'self-acceptance', 'self-awareness', 'self-compassion', 'self-reflection', 'self-regulation', 'sensations', 'sensory awareness', 'sensory experience', 'stillness', 'stress reduction', 'thoughts', 'visualization', 'waking up', 'wellbeing']
# Compassion: ['acceptance', 'active listening', 'advocacy', 'altruism', 'assist', 'attachment', 'awareness', 'benevolence', 'bonding', 'care', 'caring', 'charity', 'closeness', 'communal care', 'community', 'companionship', 'compassion', 'compassion awareness', 'compassion cultivation', 'compassion development', 'compassion fatigue', 'compassion for others', 'compassion for self', 'compassion in action', 'compassion interventions', 'compassion meditation', 'compassion mindset', 'compassion practice', 'compassion research', 'compassion skills', 'compassion training', 'compassion-focused therapy', 'compassionate communication', 'compassionate leadership', 'compassionate response', 'concern', 'connection', 'consideration', 'embrace', 'emotional attunement', 'emotional intelligence', 'emotional support', 'empathy', 'encouragement', 'engagement', 'forgiveness', 'generosity', 'gentleness', 'grace', 'healing', 'help others', 'human connection', 'humanity', 'inclusion', 'kind', 'kindness', 'listening', 'love', 'love in action', 'mercy', 'mindfulness', 'non-judgment', 'nonjudgmental', 'nurturing', 'openness', 'outreach', 'patience', 'positive regard', 'presence', 'psychological safety', 'reassurance', 'relational', 'relational care', 'relational empathy', 'resilience', 'respect', 'responsiveness', 'self-comp', 'self-compassion', 'selflessness', 'service', 'shared humanity', 'social support', 'solace', 'solidarity', 'support', 'sympathy', 'tenderness', 'trust', 'understanding', 'uplift', 'uplifting', 'upliftment', 'validation', 'vulnerability', 'warmth']

# %% [markdown]
# #### Lexicon step 1.5: Save preliminary lexicon

# %%
clean_lexicon_name = my_lexicon.name.replace(" ", "-").lower()+'_v'+my_lexicon.version.replace('.', '-').lower()

if google_drive:
  preprocessing_dir = f'{lexicon_dir}/{clean_lexicon_name}/preprocessing'

else:
  # local
  preprocessing_dir = f'{lexicon_dir}/{clean_lexicon_name}/preprocessing'

my_lexicon.save(preprocessing_dir) # may take a few minutes to appear on Google Drive
# Out:
# INFO: Saved lexicon to ./ct_lexicons//insight_v1-0/preprocessing/insight_25-01-21T21-51-44

# %% [markdown]
# For a given construct, you can review metadata, which contains the history of different actions (creating using Gen AI, adding, removing), which comes with a timestamp, the specific prompt used (including examples, definition, if any). All of these entries

# %%
import json
for construct in construct_information.keys():
	print("==="*30)
	print(construct)
	print()
	print(json.dumps(my_lexicon.constructs[construct]['tokens_metadata'], indent=4))
# Out:
# ==========================================================================================
# Insight
#
# {
#     "gpt-4o-mini, temperature-0, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-04.346697": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "analysis",
#             "awareness",
#             "awareness of self",
#             "breakthrough",
#             "clarity",
#             "clarity of feeling",
#             "clarity of mind",
#             "clarity of perception",
#             "clarity of thought",
#             "cognition",
#             "cognitive insight",
#             "comprehension",
#             "contemplation",
#             "critical thinking",
#             "depth",
#             "discernment",
#             "emotional awareness",
#             "emotional intelligence",
#             "enlightenment",
#             "epiphany",
#             "focus",
#             "growth",
#             "holistic",
#             "inner vision",
#             "insightfulness",
#             "introspection",
#             "intuition",
#             "knowledge",
#             "learning",
#             "mental clarity",
#             "mental insight",
#             "mindfulness",
#             "observation",
#             "perception",
#             "personal insight",
#             "perspective",
#             "profound understanding",
#             "psychological insight",
#             "realization",
#             "recognition",
#             "reflection",
#             "revelation",
#             "self-awareness",
#             "self-discovery",
#             "self-examination",
#             "self-knowledge",
#             "self-realization",
#             "self-reflection",
#             "synthesis",
#             "transformative insight",
#             "truth",
#             "understanding",
#             "understanding oneself",
#             "wisdom",
#             "wise"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior\nHere are some examples (include these in the list): clarity; enlightenment; wise",
#         "time_elapsed": 3.7
#     },
#     "gpt-4o-mini, temperature-0.5, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-08.028427": {
#         "action": "create",
#         "tokens": [
#             "analysis",
#             "awareness",
#             "awareness of self",
#             "breakthrough",
#             "clarity",
#             "clarity of feeling",
#             "clarity of mind",
#             "clarity of perception",
#             "clarity of thought",
#             "cognition",
#             "cognitive clarity",
#             "cognitive insight",
#             "coherence",
#             "comprehension",
#             "contemplation",
#             "critical thinking",
#             "depth",
#             "depth of understanding",
#             "discernment",
#             "emotional awareness",
#             "emotional intelligence",
#             "enlightenment",
#             "epiphany",
#             "insightfulness",
#             "introspection",
#             "intuition",
#             "knowledge",
#             "lucidity",
#             "mental clarity",
#             "mindfulness",
#             "observation",
#             "perception",
#             "perceptual insight",
#             "personal growth",
#             "perspective",
#             "profound realization",
#             "psychological insight",
#             "realization",
#             "reflection",
#             "revelation",
#             "self-awareness",
#             "self-discovery",
#             "self-examination",
#             "self-illumination",
#             "self-knowledge",
#             "self-reflection",
#             "synthesis",
#             "transformative insight",
#             "understanding",
#             "understanding self",
#             "wisdom",
#             "wise"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior\nHere are some examples (include these in the list): clarity; enlightenment; wise",
#         "time_elapsed": 3.5
#     },
#     "gpt-4o-mini, temperature-1, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-11.554414": {
#         "action": "create",
#         "tokens": [
#             "acknowledgment",
#             "analysis",
#             "awaken",
#             "awareness",
#             "behavioral insight",
#             "breakthrough",
#             "clarity",
#             "clarity of thought",
#             "cognition",
#             "cognitive",
#             "cognitive insight",
#             "comprehension",
#             "conscious thought",
#             "contemplation",
#             "critical thinking",
#             "deep understanding",
#             "delve",
#             "depth",
#             "discernment",
#             "emotional clarity",
#             "emotional intelligence",
#             "enlightenment",
#             "epiphany",
#             "focus",
#             "grasp",
#             "inner voice",
#             "inner wisdom",
#             "interpret",
#             "introspection",
#             "introspective journey",
#             "intuition",
#             "knowledge",
#             "life lessons",
#             "lucidity",
#             "mindfulness",
#             "perception",
#             "personal growth",
#             "perspective",
#             "profound realization",
#             "realization",
#             "recognition",
#             "reflection",
#             "revelation",
#             "self-awareness",
#             "self-discovery",
#             "self-knowledge",
#             "self-reflection",
#             "situational awareness",
#             "transparency",
#             "true self",
#             "truth",
#             "understanding",
#             "unveil",
#             "unveil emotions",
#             "wisdom",
#             "wise"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Insight (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Insight: the clarity of understanding of one's thoughts, feelings and behavior\nHere are some examples (include these in the list): clarity; enlightenment; wise",
#         "time_elapsed": 2.6
#     }
# }
# ==========================================================================================
# Mindfulness
#
# {
#     "gpt-4o-mini, temperature-0, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-16.047825": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "acceptance and commitment",
#             "acceptance practice",
#             "attention",
#             "awareness",
#             "awareness of body",
#             "awareness of breath",
#             "awareness of feelings",
#             "awareness of thoughts",
#             "awareness training",
#             "body scan",
#             "breathing",
#             "clarity",
#             "compassion",
#             "detachment",
#             "emotional regulation",
#             "emotions",
#             "equanimity",
#             "focus",
#             "gratitude",
#             "grounding",
#             "inner peace",
#             "intention",
#             "meditation",
#             "mindful",
#             "mindful awareness",
#             "mindful breathing",
#             "mindful communication",
#             "mindful eating",
#             "mindful journaling",
#             "mindful listening",
#             "mindful movement",
#             "mindful walking",
#             "mindfulness practice",
#             "moment to moment",
#             "non-reactivity",
#             "nonjudgemental",
#             "observation",
#             "presence",
#             "present moment",
#             "present-focused",
#             "reflection",
#             "relaxation",
#             "self-awareness",
#             "self-compassion",
#             "self-regulation",
#             "sensations",
#             "sensory awareness",
#             "stillness",
#             "stress reduction",
#             "thoughts",
#             "visualization"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Mindfulness: \"mindfulness\": \"mindfulness is the psychological process of bringing one's attention to the present moment, which can be cultivated through meditation and other practices, and is often associated with increased awareness and acceptance of one's thoughts, feelings, and bodily sensations.\",\nHere are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused",
#         "time_elapsed": 2.7
#     },
#     "gpt-4o-mini, temperature-0.5, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-18.718109": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "acceptance and commitment therapy",
#             "attention",
#             "awareness",
#             "awareness of breath",
#             "awareness training",
#             "body scan",
#             "breath",
#             "clarity",
#             "cognitive flexibility",
#             "compassion",
#             "detachment",
#             "disengagement",
#             "emotional regulation",
#             "equanimity",
#             "feelings",
#             "focus",
#             "gratitude",
#             "grounding",
#             "inner peace",
#             "intention",
#             "intention setting",
#             "loving-kindness",
#             "meditation",
#             "mental clarity",
#             "mindful",
#             "mindful eating",
#             "mindful listening",
#             "mindful movement",
#             "mindfulness-based stress reduction",
#             "moment to moment",
#             "non-jud",
#             "non-reactivity",
#             "nonjudgemental",
#             "observation",
#             "open awareness",
#             "presence",
#             "present moment",
#             "present-focused",
#             "reflection",
#             "relaxation",
#             "self-acceptance",
#             "self-awareness",
#             "self-compassion",
#             "self-reflection",
#             "sensations",
#             "sensory experience",
#             "stillness",
#             "stress reduction",
#             "thoughts",
#             "visualization"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Mindfulness: \"mindfulness\": \"mindfulness is the psychological process of bringing one's attention to the present moment, which can be cultivated through meditation and other practices, and is often associated with increased awareness and acceptance of one's thoughts, feelings, and bodily sensations.\",\nHere are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused",
#         "time_elapsed": 2.7
#     },
#     "gpt-4o-mini, temperature-1, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-21.401681": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "acceptance of feelings",
#             "acceptance of self",
#             "alertness",
#             "attention",
#             "awareness",
#             "awareness of sensations",
#             "awareness of thoughts",
#             "body scan",
#             "breath",
#             "clarity",
#             "compassion",
#             "conscious awareness",
#             "cultivating presence",
#             "deep listening",
#             "detachment",
#             "emotional regulation",
#             "equanimity",
#             "flow state",
#             "flowing",
#             "focus",
#             "gratitude",
#             "grounding",
#             "harmony",
#             "inner peace",
#             "intention",
#             "intention setting",
#             "introspection",
#             "kindness",
#             "letting go",
#             "listening",
#             "meditation",
#             "mindful",
#             "mindful breathing",
#             "mindfulness practices",
#             "moment to moment",
#             "non-reactivity",
#             "nonjudgemental",
#             "observation",
#             "openness",
#             "patience",
#             "presence",
#             "present-focused",
#             "relaxation",
#             "resilience",
#             "self-awareness",
#             "self-compassion",
#             "self-reflection",
#             "sensory awareness",
#             "stillness",
#             "stress reduction",
#             "visualization",
#             "waking up",
#             "wellbeing"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Mindfulness (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere is a definition of Mindfulness: \"mindfulness\": \"mindfulness is the psychological process of bringing one's attention to the present moment, which can be cultivated through meditation and other practices, and is often associated with increased awareness and acceptance of one's thoughts, feelings, and bodily sensations.\",\nHere are some examples (include these in the list): mindful; meditation; awareness; nonjudgemental; present-focused",
#         "time_elapsed": 2.9
#     },
#     "DML: added a few verb forms 25-01-21T21-51-37.825581": {
#         "action": "manually added",
#         "tokens": [
#             "meditate",
#             "pay attention"
#         ]
#     },
#     "DML: might capture non-compassion-related context too often 25-01-21T21-51-37.826021": {
#         "action": "remove",
#         "tokens": [
#             "being",
#             "flow"
#         ]
#     }
# }
# ==========================================================================================
# Compassion
#
# {
#     "gpt-4o-mini, temperature-0, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-24.307125": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "active listening",
#             "advocacy",
#             "altruism",
#             "benevolence",
#             "care",
#             "community",
#             "compassion",
#             "compassion awareness",
#             "compassion cultivation",
#             "compassion development",
#             "compassion fatigue",
#             "compassion for others",
#             "compassion for self",
#             "compassion in action",
#             "compassion interventions",
#             "compassion meditation",
#             "compassion mindset",
#             "compassion practice",
#             "compassion research",
#             "compassion skills",
#             "compassion training",
#             "compassion-focused therapy",
#             "compassionate communication",
#             "compassionate leadership",
#             "compassionate response",
#             "concern",
#             "connection",
#             "emotional intelligence",
#             "emotional support",
#             "empathy",
#             "encouragement",
#             "forgiveness",
#             "generosity",
#             "healing",
#             "help others",
#             "kind",
#             "kindness",
#             "listening",
#             "love",
#             "mindfulness",
#             "non-judgment",
#             "nurturing",
#             "outreach",
#             "patience",
#             "presence",
#             "relational",
#             "respect",
#             "selflessness",
#             "service",
#             "shared humanity",
#             "solidarity",
#             "support",
#             "sympathy",
#             "tenderness",
#             "understanding",
#             "vulnerability",
#             "warmth"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): compassion; love; kind; help others",
#         "time_elapsed": 3.3
#     },
#     "gpt-4o-mini, temperature-0.5, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-27.604252": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "active listening",
#             "altruism",
#             "awareness",
#             "benevolence",
#             "caring",
#             "charity",
#             "community",
#             "compassion",
#             "compassion cultivation",
#             "compassion fatigue",
#             "compassion in action",
#             "compassion meditation",
#             "compassion training",
#             "compassion-focused therapy",
#             "concern",
#             "connection",
#             "emotional attunement",
#             "emotional intelligence",
#             "emotional support",
#             "empathy",
#             "encouragement",
#             "forgiveness",
#             "generosity",
#             "grace",
#             "healing",
#             "help others",
#             "human connection",
#             "kind",
#             "kindness",
#             "love",
#             "love in action",
#             "mercy",
#             "mindfulness",
#             "non-judgment",
#             "nurturing",
#             "outreach",
#             "patience",
#             "positive regard",
#             "presence",
#             "psychological safety",
#             "relational care",
#             "relational empathy",
#             "respect",
#             "responsiveness",
#             "self-comp",
#             "selflessness",
#             "service",
#             "shared humanity",
#             "social support",
#             "solidarity",
#             "support",
#             "sympathy",
#             "tenderness",
#             "understanding",
#             "uplifting",
#             "validation",
#             "warmth"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): compassion; love; kind; help others",
#         "time_elapsed": 3.0
#     },
#     "gpt-4o-mini, temperature-1, top_p-1, max_tokens-150, seed-42, 25-01-21T21-51-30.595736": {
#         "action": "create",
#         "tokens": [
#             "acceptance",
#             "active listening",
#             "advocacy",
#             "altruism",
#             "assist",
#             "attachment",
#             "awareness",
#             "benevolence",
#             "bonding",
#             "caring",
#             "charity",
#             "closeness",
#             "communal care",
#             "community",
#             "companionship",
#             "compassion",
#             "compassion fatigue",
#             "compassion training",
#             "connection",
#             "consideration",
#             "embrace",
#             "emotional intelligence",
#             "emotional support",
#             "empathy",
#             "encouragement",
#             "engagement",
#             "forgiveness",
#             "generosity",
#             "gentleness",
#             "grace",
#             "healing",
#             "help others",
#             "humanity",
#             "inclusion",
#             "kind",
#             "kindness",
#             "listening",
#             "love",
#             "mercy",
#             "mindfulness",
#             "nonjudgmental",
#             "nurturing",
#             "openness",
#             "outreach",
#             "patience",
#             "positive regard",
#             "reassurance",
#             "relational",
#             "resilience",
#             "respect",
#             "responsiveness",
#             "self-compassion",
#             "service",
#             "social support",
#             "solace",
#             "solidarity",
#             "support",
#             "sympathy",
#             "tenderness",
#             "trust",
#             "understanding",
#             "uplift",
#             "upliftment",
#             "warmth"
#         ],
#         "prompt": "Provide many single words and some short phrases (all in lowercase unless the word is generally in uppercase) related to Compassion (in the psychology domain). Each token should be separated by a semicolon. Do not return duplicate tokens. Do not provide any explanation or additional text beyond the tokens.\nHere are some examples (include these in the list): compassion; love; kind; help others",
#         "time_elapsed": 2.8
#     }
# }

# %% [markdown]
# Also available in `_metadata.json` file when saving the lexicon

# %% [markdown]
# #### Lexicon step 1.6: Extract counts
#
# Calibration step: this can be done on a examples you come up with or on training set to make sure it's doing a good job

# %%
# First lemmatize lexicon tokens

my_lexicon = lexicon.lemmatize_tokens(my_lexicon) # if not this will be done automatically, but won't be saved in my_lexicon.
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  3.42it/s]

# %%
# Now count whether tokens appear in document:

counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,
                                                                                      normalize = False,
                                                                                      )
display(counts)
# Out:
# extracting...
# 100%|██████████| 3/3 [00:00<00:00, 2707.75it/s]
#    document_id                                           document  Insight  \
# 0            0  Every time I speak with my cousin Bob, I have ...        2
# 1            1       He meditates a lot, but he's not super smart        0
# 2            2                              He is too competitive        0
#
#    Mindfulness  Compassion  word_count
# 0            1           0          17
# 1            1           0           8
# 2            0           0           4

# %%
# Interpret counts: visualize matches in context  

for construct in construct_information.keys():
	print(f'------- Matches for {construct}:')
	lexicon.highlight_matches(documents, construct, matches_construct2doc, max_matches = 2)
	print()
# Out:
# ------- Matches for Insight:
#
# ------- Matches for Mindfulness:
# He <mark>meditate</mark>s a lot, but he's not super smart
# ------- Matches for Compassion:

# %% [markdown]
# #### Lexicon step 1.7: Validate with experts or just crowdsourcing (OPTIONAL)
#
# 1.7.1. Create `human_ratings/` folder

# %%
perform_human_ratings = False

if perform_human_ratings:
	clean_lexicon_name = my_lexicon.name.replace(" ", "-")+'_v'+my_lexicon.version.replace('.', '-').lower()

	if google_drive:
		preprocessing_dir = f'{lexicon_dir}/{clean_lexicon_name}/human_ratings'

	else:
		# local
		ratings_dir = f'{lexicon_dir}/{clean_lexicon_name}/human_ratings/' 
		



	
	os.makedirs(ratings_dir, exist_ok=True)
	print(f'saving to {ratings_dir}')

# %% [markdown]
# 1.7.2. Take the `<date>_ratings.csv` in the `preprocessing/` directory and send a copy to each human rater (aka coder, annotator) with their ID appended to the filename. Here we'll automatically find the last one created.

# %%
if perform_human_ratings:

	# I'll create three duplicates of the ratings file identifying each file with raters initials

	# or use digit IDs:
	n_raters = 3
	rater_ids = [str(i).zfill(3) for i in range(n_raters)] # ['001', '002', '003']
	# Save names for each ID separately in case you need to check in about a certain rating. 


	copy_annotation_file_to_ratings_dir = False

	if copy_annotation_file_to_ratings_dir:
		path_to_unvalidated_lexicon = os.listdir(preprocessing_dir)
		path_to_unvalidated_lexicon = [n for n in path_to_unvalidated_lexicon if n.endswith('ratings.csv')][0]

		for rater_id in rater_ids:
			new_path = path_to_unvalidated_lexicon.replace('preprocessing', 'human_ratings').replace('.csv', f'_{rater_id}.csv')
			# copy from preprocessing to human_raters
			shutil.copy(path_to_unvalidated_lexicon, new_path)


	# Now you have this file in human_ratings Insight_24-08-08T21-29-52_ratings_001.csv, ..._002.csv, ..._003.csv.

# %% [markdown]
# 1.7.3. Have them rate following these or similar instructions. Save files as csv instead of excel to use the code below
#
# https://github.com/danielmlow/construct-tracker/blob/daniels_branch/tutorials/lexicon%20risk%20factors%20final%20instructions.pdf
#
# [Google docs version](https://docs.google.com/document/d/1pu89KmU31grhzFeZmwOoN0U2plSWaDMSKWYUXy_acL4/edit?usp=sharing)
#
# In this toy example, I just duplicated the files as an example so they all have the same ratings. One of the raters added some suggestions. The instructions can take them as 3/3 or the rater can add them at the bottom and can add their rating. Then these can be sent to other raters in a second round before going onto the next step.

# %% [markdown]
# 1.7.4. Take average ratings, discard tokens below a certain average

# %%
if perform_human_ratings:
    # average_ratings

    rating_files = os.listdir(ratings_dir)
    rating_files = [n for n in rating_files if n not in ['.DS_Store']]
    print(rating_files) # this should not be empty, you should have some human_rating files for each rater

# %%
if perform_human_ratings:
	from construct_tracker.lexicon import merge_rating_dfs

	# Copy and paste correct files here to make sure you don't add the same ratings with two different extensions:
	rating_files = [
		'Insight_24-08-08T21-29-52_ratings_001.csv', 'Insight_24-08-08T21-29-52_ratings_002.csv', 'Insight_24-08-08T21-29-52_ratings_003.csv', 
		]

	# Ratings by all raters in a single dictionary
	# all_ratings_per_construct_dict = {
		# construct_1: {token_1: [rating_1, rating_2, ...], token_2: [rating_1, rating_2, ...], ...},
		# construct_2: {token_1: [rating_1, rating_2, ...], token_2: [rating_1, rating_2, ...], ...},
		# ...} 

	all_ratings_per_construct_dict = merge_rating_dfs(ratings_dir, rating_files, construct_information.keys())

	# Save ratings to lexicon
	todays_date = datetime.datetime.utcnow().strftime("%y-%m-%d") 
	my_lexicon.set_attribute('ratings_'+todays_date, all_ratings_per_construct_dict)

# %%
if perform_human_ratings:
	# Average and remove tokens < a threshold
	ratings_avg, ratings_removed = lexicon.avg_above_thresh(all_ratings_per_construct_dict, thresh = 1.3)

	# Remove tokens with low avg. ratings
	for construct in ratings_removed:
		remove_tokens = ratings_removed[construct]
		my_lexicon.remove(construct, remove_tokens=remove_tokens, 
						source = my_lexicon.creator + ": tokens rated lower than 1.3 by raters")

# %%
my_lexicon.name
# Out:
# 'Insight'

# %%
clean_lexicon_name
# Out:
# 'insight_v1-0'

# %%
if perform_human_ratings:

	# Average and only keep tokens 3/3 on protoypicality. These are definitely related to the construct and can be used for CTS or to avoid false positives. 
	ratings_avg_prototypical, ratings_removed_prototypical = lexicon.avg_above_thresh(all_ratings_per_construct_dict, thresh = 3) # set to 3 or perhaps above 2 like 2.1. 

	my_lexicon_prototypes = copy.deepcopy(my_lexicon)
	my_lexicon_prototypes.name = my_lexicon.name + ' prototypes'

	# Remove tokens with low avg. ratings
	for construct in ratings_removed_prototypical:
		remove_tokens = ratings_removed[construct]
		my_lexicon_prototypes.remove(construct, remove_tokens=remove_tokens, 
									source = my_lexicon_prototypes.creator + ": tokens rated lower than 3 by raters")



	# Save final prototypes lexicon
	
	my_lexicon_prototypes.save(f'{lexicon_dir}/{clean_lexicon_name}/', filename = clean_lexicon_name+'_validated_prototypes-3-3') # save lexicon protocotypes 3/3

# %%
if perform_human_ratings:
	# List construct with less than 10 tokens (which might be too few for a lexicon but sufficient for CTS method). [] means none.
	print([(k,v) for k,v in ratings_avg_prototypical.items() if len(v)<10])

# %% [markdown]
# 1.7.5. Inter-rater reliability (OPTIONAL)
#
# 	See manuscript for more information

# %%
# In this toy example, all raters rated the tokens the same, so IRR = 1 out of 1. 

if perform_human_ratings:
	from construct_tracker.utils import irr
	import numpy as np


	# df = all_ratings_per_construct_dict
	# or from: all_ratings_per_construct_dict = my_lexicon.get_attribute('ratings_24-08-08')

	# TODO: turn into function
	cohens_kappa_all = {}
	fleiss_kappa_all = {}
	for construct, tokens in all_ratings_per_construct_dict.items():
		construct_c_ratings = list(tokens.values())
		construct_c_ratings_mode = int(np.median([len(n) for n in construct_c_ratings])) # construct_c_ratings)
		construct_c_ratings_all_annotated = []
		for token_i_ratings in construct_c_ratings:
			token_i_ratings = list(token_i_ratings)
		
			
			if len(token_i_ratings)==construct_c_ratings_mode and np.mean(token_i_ratings)>1.3:
			# 	token_i_ratings = token_i_ratings + [np.round(np.mean(token_i_ratings),0)]

				construct_c_ratings_all_annotated.append(token_i_ratings)
				
		# If I dont have them all the same shape, can't calculate
		construct_c_ratings = np.array(construct_c_ratings_all_annotated)
		construct_c_ratings = construct_c_ratings.astype(int)
		
		if construct_c_ratings.shape[1] == 2:
			# kappa = binary_inter_rater_reliability(construct_c_ratings[:,0], construct_c_ratings[:,1])
			kappa = irr.cohens_kappa(construct_c_ratings)
			cohens_kappa_all[construct.replace('_include','')] = kappa
			print(f"Cohen's Weighted Kappa (2 raters) for {construct}: {kappa}")
		elif construct_c_ratings.shape[1] >= 3:
			kappa = irr.calculate_fleiss_kappa(construct_c_ratings)
			fleiss_kappa_all[construct.replace('_include','')] = kappa
			print(f"Fleiss' Kappa (3 or more raters) for {construct}: {kappa}")


	weighted_kappa = pd.DataFrame(cohens_kappa_all, index = ['weighted_kappa']).T.mean()
	fleis_kappa = pd.DataFrame(fleiss_kappa_all, index = ['fleiss_kappa']).T


	display(weighted_kappa)
	display(fleis_kappa)

# %% [markdown]
# #### Lexicon step 1.8: Save final lexicon

# %%
clean_lexicon_name
# Out:
# 'insight_v1-0'

# %%
# Main lexicon in the main folder. 
my_lexicon.save(f'{lexicon_dir}/{clean_lexicon_name}/', filename = f'{clean_lexicon_name}_validated') # save lexicon
# Out:
# INFO: Saved lexicon to ./ct_lexicons//insight_v1-0//insight_v1-0_validated_25-01-21T21-52-07

# %% [markdown]
# #### Lexicon step 1.9: Final feature extraction
#
# If you want to load lexicon in a different script in the future:
# ```python
# path = f'./ct_lexicons/{clean_lexicon_name}/'
# my_lexicon = load_lexicon(path = path)
# ```

# %%
# Now count whether tokens appear in document:

# We'll set normalize to True. Whether to normalize the extracted features by word count. 3 matches in a short document would be weighed higher than in a long document.
counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,
                                                                                      normalize = False,
                                                                                      )
display(counts)
# Might be worth calibrating (removing words that create false positives too often) on a training set.
# Out:
# extracting...
# 100%|██████████| 3/3 [00:00<00:00, 1799.62it/s]
#    document_id                                           document  Insight  \
# 0            0  Every time I speak with my cousin Bob, I have ...        2
# 1            1       He meditates a lot, but he's not super smart        0
# 2            2                              He is too competitive        0
#
#    Mindfulness  Compassion  word_count
# 0            1           0          17
# 1            1           0           8
# 2            0           0           4

# %%
# Now count whether tokens appear in document:

normalize = True
# We'll set normalize to True. Whether to normalize the extracted features by word count. 3 matches in a short document would be weighed higher than in a long document.
counts, matches_by_construct, matches_doc2construct, matches_construct2doc  = my_lexicon.extract(documents,
                                                                                      normalize = normalize,
                                                                                      )
display(counts)
# Might be worth calibrating (removing words that create false positives too often) on a training set.
# Out:
# extracting...
# 100%|██████████| 3/3 [00:00<00:00, 1506.76it/s]
#    document_id                                           document   Insight  \
# 0            0  Every time I speak with my cousin Bob, I have ...  0.117647
# 1            1       He meditates a lot, but he's not super smart  0.000000
# 2            2                              He is too competitive  0.000000
#
#    Mindfulness  Compassion  word_count
# 0     0.058824         0.0          17
# 1     0.125000         0.0           8
# 2     0.000000         0.0           4

# %%
# save counts
output_dir = './data/insight_project/'
os.makedirs(output_dir, exist_ok=True)
counts.to_csv(f'{output_dir}insight_lexicon_counts_normalize-{normalize}.csv', index = False)
print('saved to', f'{output_dir}insight_lexicon_counts_normalize-{normalize}.csv')
# Out:
# saved to ./data/insight_project/insight_lexicon_counts_normalize-True.csv
